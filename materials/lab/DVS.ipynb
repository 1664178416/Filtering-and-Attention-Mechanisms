# %%
import torch
import sys
import torch.nn.functional as F
from torch.cuda import amp
from spikingjelly.activation_based import functional, surrogate, neuron
from spikingjelly.activation_based.model import parametric_lif_net
from spikingjelly.datasets.dvs128_gesture import DVS128Gesture
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
import time
import os
import argparse
import datetime
# Out:
# d:\dev\anaconda3\envs\snn\lib\site-packages\cupy\_environment.py:217: UserWarning: CUDA path could not be detected. Set CUDA_PATH environment variable if CuPy fails to load.
#   warnings.warn(

# %%
import numpy as np
if not hasattr(np, 'int'):
    np.int = int

# %%
from spikingjelly.datasets.dvs128_gesture import DVS128Gesture

root_dir = '../datasets/DVS128Gesture'
train_set = DVS128Gesture(root_dir, train=True, data_type='event')
# Out:
# The [../datasets/DVS128Gesture\download] directory for saving downloaded files already exists, check files...
# Mkdir [../datasets/DVS128Gesture\extract].
# Extract [../datasets/DVS128Gesture\download\DvsGesture.tar.gz] to [../datasets/DVS128Gesture\extract].
# Mkdir [../datasets/DVS128Gesture\events_np].
# Start to convert the origin data from [../datasets/DVS128Gesture\extract] to [../datasets/DVS128Gesture\events_np] in np.ndarray format.
# Mkdir [('../datasets/DVS128Gesture\\events_np\\train', '../datasets/DVS128Gesture\\events_np\\test').
# Mkdir ['0', '1', '10', '2', '3', '4', '5', '6', '7', '8', '9'] in [../datasets/DVS128Gesture\events_np\train] and ['0', '1', '10', '2', '3', '4', '5', '6', '7', '8', '9'] in [../datasets/DVS128Gesture\events_np\test].
# Start the ThreadPoolExecutor with max workers = [16].
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user04_fluorescent_led.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\0\user04_fluorescent_led_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user04_fluorescent.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\1\user04_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user04_fluorescent_0.npz] saved.[../datasets/DVS128Gesture\events_np\train\2\user04_fluorescent_led_0.npz] saved.
#
# [../datasets/DVS128Gesture\events_np\train\3\user04_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user04_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user04_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user04_fluorescent_led_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user02_fluorescent_led.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\0\user02_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user04_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user04_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user04_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user04_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user02_fluorescent_led_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user02_led.aedat] to samples.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user02_fluorescent.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\5\user04_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user04_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user02_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user02_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user02_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user04_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user02_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user04_fluorescent_led_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user02_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user02_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user04_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user02_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user04_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user02_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user02_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user04_fluorescent_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user04_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user02_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user02_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user02_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user04_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user04_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user02_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user02_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user04_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user02_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user02_led_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user02_natural.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\7\user02_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user04_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user02_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user02_fluorescent_led_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user02_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user02_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user02_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user02_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user02_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user02_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user02_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user02_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user02_led_1.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user01_led.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\7\user02_fluorescent_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user02_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user02_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user02_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user01_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user02_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user02_led_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user03_fluorescent_led.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\3\user02_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user02_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user01_led_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user03_fluorescent.aedat] to samples.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user03_led.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\10\user02_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user03_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user02_natural_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user01_fluorescent.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\10\user02_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user01_led_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user03_natural.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\0\user03_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user03_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user03_led_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user01_fluorescent_led.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\0\user01_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user02_natural_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user02_lab.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\3\user01_led_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user01_lab.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\0\user03_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user01_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user01_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user03_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user03_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user02_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user03_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user02_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user01_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user02_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user03_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user01_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user01_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user02_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user01_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user03_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user03_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user03_led_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user01_natural.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\1\user01_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user03_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user01_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user02_natural_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user02_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user01_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user03_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user01_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user01_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user01_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user03_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user03_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user02_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user01_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user03_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user01_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user01_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user02_natural_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user04_led.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\4\user02_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user03_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user03_fluorescent_led_0.npz] saved.[../datasets/DVS128Gesture\events_np\train\4\user01_fluorescent_0.npz] saved.
#
# [../datasets/DVS128Gesture\events_np\train\4\user03_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user01_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user01_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user04_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user03_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user01_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user03_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user01_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user04_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user03_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user02_lab_0.npz] saved.[../datasets/DVS128Gesture\events_np\train\10\user02_natural_0.npz] saved.
#
# [../datasets/DVS128Gesture\events_np\train\5\user01_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user01_led_1.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user05_fluorescent.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\5\user03_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user04_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user01_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user03_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user03_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user01_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user05_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user03_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user01_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user02_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user04_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user01_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user03_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user03_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user01_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user03_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user05_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user01_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user03_fluorescent_led_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user01_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user04_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user02_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user01_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user01_led_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user04_natural.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\2\user05_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user01_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user03_fluorescent_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user03_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user03_natural_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user05_fluorescent_led.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\8\user03_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user04_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user01_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user04_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user05_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user05_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user01_fluorescent_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user01_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user04_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user01_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user02_lab_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user03_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user03_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user01_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user03_natural_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user03_led_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user04_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user05_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user01_fluorescent_led_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user05_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user03_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user01_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user03_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user04_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user01_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user04_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user02_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user03_natural_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user05_lab.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\5\user05_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user01_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user05_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user03_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user01_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user03_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user01_lab_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user04_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user01_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user02_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user03_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user04_led_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user05_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user05_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user03_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user05_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user01_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user01_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user05_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user04_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user04_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user05_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user01_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user03_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user01_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user05_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user03_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user05_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user01_natural_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user04_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user02_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user01_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user04_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user05_fluorescent_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user05_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user01_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user04_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user05_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user05_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user04_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user01_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user05_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user01_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user05_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user05_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user04_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user05_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user01_natural_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user05_led.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\10\user05_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user05_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user04_natural_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user05_fluorescent_led_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user05_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user01_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user05_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user04_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user05_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user05_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user05_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user05_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user04_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user05_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user05_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user04_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user05_lab_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user05_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user05_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user05_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user05_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user05_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user05_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user05_lab_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user07_fluorescent_led.aedat] to samples.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user05_natural.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\7\user05_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user07_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user05_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user05_led_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user07_fluorescent_led_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user07_fluorescent.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\1\user05_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user05_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user05_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user07_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user07_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user05_led_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user07_led.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\3\user05_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user05_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user07_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user07_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user07_led_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user06_fluorescent_led.aedat] to samples.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user06_lab.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\4\user05_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user07_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user07_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user06_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user07_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user06_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user07_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user05_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user07_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user06_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user06_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user07_fluorescent_led_0.npz] saved.[../datasets/DVS128Gesture\events_np\train\6\user05_natural_0.npz] saved.
#
# [../datasets/DVS128Gesture\events_np\train\2\user07_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user07_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user06_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user07_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user06_fluorescent_led_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user06_fluorescent.aedat] to samples.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user08_fluorescent.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\7\user05_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user07_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user07_fluorescent_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user06_led.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\7\user07_fluorescent_led_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user06_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user08_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user05_natural_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user07_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user07_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user06_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user06_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user06_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user07_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user06_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user08_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user07_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user07_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user06_fluorescent_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user08_fluorescent_led.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\8\user05_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user06_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user06_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user07_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user06_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user08_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user07_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user05_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user08_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user07_fluorescent_1.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user08_led.aedat] to samples.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user06_natural.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\2\user06_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user07_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user06_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user06_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user06_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user07_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user07_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user08_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user05_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user08_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user06_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user08_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user06_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user06_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user06_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user07_led_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user07_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user06_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user08_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user06_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user08_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user08_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user06_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user06_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user07_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user06_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user06_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user08_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user07_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user08_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user06_lab_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user08_led_0.npz] saved.[../datasets/DVS128Gesture\events_np\train\9\user07_led_0.npz] saved.
#
# [../datasets/DVS128Gesture\events_np\train\7\user06_fluorescent_led_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user06_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user08_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user06_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user06_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user06_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user08_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user07_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user08_led_0.npz] saved.[../datasets/DVS128Gesture\events_np\train\8\user06_fluorescent_led_0.npz] saved.
#
# [../datasets/DVS128Gesture\events_np\train\7\user08_fluorescent_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user09_fluorescent.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\6\user06_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user06_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user06_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user08_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user06_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user08_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user06_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user08_fluorescent_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user09_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user06_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user06_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user06_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user08_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user06_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user08_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user09_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user08_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user06_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user08_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user06_led_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user06_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user08_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user09_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user06_fluorescent_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user08_fluorescent_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user08_lab.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\7\user08_fluorescent_led_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user06_natural_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user09_fluorescent_led.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\8\user06_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user08_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user08_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user06_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user09_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user06_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user08_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user08_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user08_led_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user09_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user06_natural_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user09_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user06_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user08_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user08_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user06_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user09_fluorescent_led_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user07_lab.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\8\user06_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user08_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user09_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user06_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user08_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user07_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user09_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user08_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user06_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user08_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user09_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user07_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user08_lab_0.npz] saved.[../datasets/DVS128Gesture\events_np\train\10\user06_natural_0.npz] saved.
#
# [../datasets/DVS128Gesture\events_np\train\3\user09_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user08_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user09_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user07_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user09_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user08_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user09_fluorescent_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user09_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user08_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user07_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user09_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user08_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user09_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user09_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user07_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user09_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user08_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user09_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user07_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user09_fluorescent_led_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user08_lab_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user07_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user09_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user08_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user07_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user09_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user08_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user07_lab_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user09_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user08_lab_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user10_fluorescent.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\8\user07_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user10_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user07_lab_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user09_lab.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\1\user10_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user07_lab_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user10_led.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\0\user09_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user10_fluorescent_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user10_fluorescent_led.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\0\user10_led_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user12_fluorescent_led.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\3\user10_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user10_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user09_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user10_led_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user09_natural.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\1\user10_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user12_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user10_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user09_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user10_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user10_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user09_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user12_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user10_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user09_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user10_fluorescent_led_0.npz] saved.[../datasets/DVS128Gesture\events_np\train\3\user10_led_0.npz] saved.
#
# [../datasets/DVS128Gesture\events_np\train\1\user09_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user12_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user10_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user09_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user10_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user10_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user09_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user12_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user10_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user10_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user10_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user09_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user09_natural_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user12_led.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\4\user12_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user10_fluorescent_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user10_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user09_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user12_led_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user13_fluorescent.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\4\user09_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user12_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user10_fluorescent_led_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user09_led.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\7\user09_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user13_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user10_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user10_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user12_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user12_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user09_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user10_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user13_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user09_lab_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user09_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user10_led_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user12_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user10_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user12_fluorescent_led_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user13_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user09_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user09_natural_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user10_lab.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\7\user10_fluorescent_led_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user10_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user10_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user12_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user12_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user09_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user09_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user13_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user10_lab_0.npz] saved.[../datasets/DVS128Gesture\events_np\train\7\user09_natural_0.npz] saved.
#
# [../datasets/DVS128Gesture\events_np\train\7\user12_fluorescent_led_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user10_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user10_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user09_lab_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user13_fluorescent_led.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\4\user12_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user09_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user13_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user10_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user09_natural_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user10_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user12_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user10_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user13_fluorescent_led_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user13_led.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\train\5\user12_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user13_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user10_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\8\user09_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user12_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user09_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\0\user13_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user10_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user13_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user12_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\6\user13_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\9\user09_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user12_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\1\user13_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\3\user10_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user13_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user09_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user13_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\7\user12_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\10\user09_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\2\user13_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\4\user10_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\train\5\user09_led_0.npz] saved.
# ...
#
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user27_natural.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\test\1\user27_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\4\user27_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\6\user26_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\3\user26_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\3\user27_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\9\user25_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\5\user24_fluorescent_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user28_fluorescent_led.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\test\0\user27_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\8\user24_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\2\user27_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user26_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\5\user27_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\4\user26_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\0\user28_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\4\user27_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\10\user25_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\1\user27_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\9\user24_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\6\user24_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user26_led_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\6\user27_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\3\user27_led_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user28_fluorescent.aedat] to samples.[../datasets/DVS128Gesture\events_np\test\2\user27_natural_0.npz] saved.
#
# [../datasets/DVS128Gesture\events_np\test\1\user28_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\5\user26_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\5\user27_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\8\user26_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user24_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\10\user24_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user27_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\0\user28_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\2\user28_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\6\user26_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\6\user27_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\4\user27_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user24_fluorescent_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\3\user27_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\9\user26_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user27_fluorescent_led_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\1\user28_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user26_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\3\user28_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\8\user27_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user27_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\10\user26_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\8\user24_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\5\user27_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\2\user28_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\4\user27_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user27_fluorescent_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\9\user27_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user26_natural_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\4\user28_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\6\user27_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\3\user28_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\5\user27_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\9\user24_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\8\user27_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\10\user27_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\8\user26_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\5\user28_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user27_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\4\user28_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\6\user27_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\9\user27_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\9\user26_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\6\user28_fluorescent_led_0.npz] saved.[../datasets/DVS128Gesture\events_np\test\7\user27_led_1.npz] saved.
#
# [../datasets/DVS128Gesture\events_np\test\5\user28_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\10\user24_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user27_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\10\user26_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\10\user27_fluorescent_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user26_lab.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\test\8\user27_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user28_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\6\user28_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user27_natural_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\0\user26_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user28_fluorescent_led_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\9\user27_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user28_fluorescent_0.npz] saved.[../datasets/DVS128Gesture\events_np\test\8\user27_natural_0.npz] saved.
#
# [../datasets/DVS128Gesture\events_np\test\8\user28_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\10\user27_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\1\user26_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\9\user27_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user28_fluorescent_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\9\user28_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\8\user28_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\10\user27_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\2\user26_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\10\user28_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\9\user28_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\3\user26_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\10\user28_fluorescent_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user28_natural.aedat] to samples.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user28_led.aedat] to samples.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user29_fluorescent.aedat] to samples.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user29_fluorescent_led.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\test\0\user28_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\0\user28_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\4\user26_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\0\user29_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\0\user29_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\1\user28_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\1\user28_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\1\user29_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\1\user29_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\2\user29_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\2\user28_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\2\user28_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\5\user26_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\2\user29_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\3\user28_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\3\user28_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\3\user29_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\3\user29_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\6\user26_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\4\user28_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\4\user28_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\4\user29_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\4\user29_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user26_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\5\user28_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\5\user29_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\5\user29_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\5\user28_natural_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user28_lab.aedat] to samples.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user29_led.aedat] to samples.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user29_natural.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\test\6\user29_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\6\user28_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\6\user29_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user26_lab_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\0\user28_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\6\user28_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\0\user29_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\0\user29_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user29_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user28_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\1\user29_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user29_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user28_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\1\user29_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\1\user28_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\2\user29_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\2\user29_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user29_fluorescent_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user28_natural_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user28_led_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\8\user26_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user29_fluorescent_led_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\2\user28_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\8\user28_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\8\user29_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\8\user28_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\3\user29_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\8\user29_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\9\user29_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\3\user29_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\9\user28_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\9\user28_natural_0.npz] saved.
# Start to split [../datasets/DVS128Gesture\extract\DvsGesture\user29_lab.aedat] to samples.
# [../datasets/DVS128Gesture\events_np\test\10\user29_fluorescent_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\9\user29_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\3\user28_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\10\user29_fluorescent_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\0\user29_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\4\user29_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\1\user29_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\10\user28_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\4\user29_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\9\user26_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\10\user28_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\2\user29_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\5\user29_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\5\user29_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\4\user28_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\6\user29_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\10\user26_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user29_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\6\user29_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user29_led_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user29_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\8\user29_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\3\user29_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\9\user29_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user29_natural_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\10\user29_led_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\8\user29_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\5\user28_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\9\user29_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\10\user29_natural_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\4\user29_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\6\user28_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\5\user29_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user28_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user28_lab_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\8\user28_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\6\user29_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\9\user28_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user29_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\7\user29_lab_1.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\10\user28_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\8\user29_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\9\user29_lab_0.npz] saved.
# [../datasets/DVS128Gesture\events_np\test\10\user29_lab_0.npz] saved.
# Used time = [442.51s].
# All aedat files have been split to samples and saved into [('../datasets/DVS128Gesture\\events_np\\train', '../datasets/DVS128Gesture\\events_np\\test')].

# %%
def main():
    # python -m spikingjelly.activation_based.examples.classify_dvsg -T 16 -device cuda:0 -b 16 -epochs 64 -data-dir /datasets/DVSGesture/ -amp -cupy -opt adam -lr 0.001 -j 8

    parser = argparse.ArgumentParser(description='Classify DVS Gesture')
    parser.add_argument('-T', default=16, type=int, help='simulating time-steps')                                   #   16
    parser.add_argument('-device', default='cuda:0', help='device')                                                 #   cuda:0    
    parser.add_argument('-b', default=16, type=int, help='batch size')                                              #   16
    parser.add_argument('-epochs', default=32, type=int, metavar='N',
                        help='number of total epochs to run')                                                       #   32
    parser.add_argument('-j', default=4, type=int, metavar='N',
                        help='number of data loading workers (default: 4)')                                         #   4
    parser.add_argument('-data-dir', type=str, help='root dir of DVS Gesture dataset',default='../datasets/DVS128Gesture')
    parser.add_argument('-out-dir', type=str, default='./logs', help='root dir for saving logs and checkpoint')
    parser.add_argument('-resume', type=str, help='resume from the checkpoint path')
    parser.add_argument('-amp', action='store_true', help='automatic mixed precision training',default= True)       #   amp
    parser.add_argument('-cupy', action='store_true', help='use cupy backend', default=True)                        #   cupy
    parser.add_argument('-opt', type=str, help='use which optimizer. SDG or Adam', default='adam')                  #   Adam
    parser.add_argument('-momentum', default=0.9, type=float, help='momentum for SGD')                              #   momentum = 0.9
    parser.add_argument('-lr', default=0.001, type=float, help='learning rate')                                     #   lr = 0.001
    parser.add_argument('-channels', default=128, type=int, help='channels of CSNN')                                #   128

    args, _ = parser.parse_known_args()  # 忽略 Jupyter 自动添加的 -f 参数
    print(args)

    net = parametric_lif_net.DVSGestureNet(channels=args.channels, spiking_neuron=neuron.LIFNode, surrogate_function=surrogate.ATan(), detach_reset=True)

    functional.set_step_mode(net, 'm')
    if args.cupy:
        functional.set_backend(net, 'cupy', instance=neuron.LIFNode)

    print(net)


    net.to(args.device)

    train_set = DVS128Gesture(root=args.data_dir, train=True, data_type='frame', frames_number=args.T, split_by='number')
    test_set = DVS128Gesture(root=args.data_dir, train=False, data_type='frame', frames_number=args.T, split_by='number')



    train_data_loader = torch.utils.data.DataLoader(
        dataset=train_set,
        batch_size=args.b,
        shuffle=True,
        drop_last=True,
        num_workers=args.j,
        pin_memory=True
    )

    test_data_loader = torch.utils.data.DataLoader(
        dataset=test_set,
        batch_size=args.b,
        shuffle=True,
        drop_last=False,
        num_workers=args.j,
        pin_memory=True
    )


    scaler = None
    if args.amp:
        scaler = amp.GradScaler()

    start_epoch = 0
    max_test_acc = -1

    optimizer = None
    if args.opt == 'sgd':
        optimizer = torch.optim.SGD(net.parameters(), lr=args.lr, momentum=args.momentum)
    elif args.opt == 'adam':
        optimizer = torch.optim.Adam(net.parameters(), lr=args.lr)
    else:
        raise NotImplementedError(args.opt)

    lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, args.epochs)

    if args.resume:
        checkpoint = torch.load(args.resume, map_location='cpu')
        net.load_state_dict(checkpoint['net'])
        optimizer.load_state_dict(checkpoint['optimizer'])
        lr_scheduler.load_state_dict(checkpoint['lr_scheduler'])
        start_epoch = checkpoint['epoch'] + 1
        max_test_acc = checkpoint['max_test_acc']

    out_dir = os.path.join(args.out_dir, f'T{args.T}_b{args.b}_{args.opt}_lr{args.lr}_c{args.channels}')

    if args.amp:
        out_dir += '_amp'

    if args.cupy:
        out_dir += '_cupy'

    if not os.path.exists(out_dir):
        os.makedirs(out_dir)
        print(f'Mkdir {out_dir}.')

    writer = SummaryWriter(out_dir, purge_step=start_epoch)
    with open(os.path.join(out_dir, 'args.txt'), 'w', encoding='utf-8') as args_txt:
        args_txt.write(str(args))
        args_txt.write('\n')
        args_txt.write(' '.join(sys.argv))

    for epoch in range(start_epoch, args.epochs):
        start_time = time.time()
        net.train()
        train_loss = 0
        train_acc = 0
        train_samples = 0
        for frame, label in train_data_loader:
            optimizer.zero_grad()
            frame = frame.to(args.device)
            frame = frame.transpose(0, 1)  # [N, T, C, H, W] -> [T, N, C, H, W]
            label = label.to(args.device)
            label_onehot = F.one_hot(label, 11).float()

            if scaler is not None:
                with amp.autocast():
                    out_fr = net(frame).mean(0)
                    loss = F.mse_loss(out_fr, label_onehot)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()
            else:
                out_fr = net(frame).mean(0)
                loss = F.mse_loss(out_fr, label_onehot)
                loss.backward()
                optimizer.step()

            train_samples += label.numel()
            train_loss += loss.item() * label.numel()
            train_acc += (out_fr.argmax(1) == label).float().sum().item()

            functional.reset_net(net)

        train_time = time.time()
        train_speed = train_samples / (train_time - start_time)
        train_loss /= train_samples
        train_acc /= train_samples

        writer.add_scalar('train_speed', train_speed, epoch)
        writer.add_scalar('train_loss', train_loss, epoch)
        writer.add_scalar('train_acc', train_acc, epoch)
        lr_scheduler.step()

        net.eval()
        test_loss = 0
        test_acc = 0
        test_samples = 0
        with torch.no_grad():
            for frame, label in test_data_loader:
                frame = frame.to(args.device)
                frame = frame.transpose(0, 1)  # [N, T, C, H, W] -> [T, N, C, H, W]
                label = label.to(args.device)
                label_onehot = F.one_hot(label, 11).float()
                out_fr = net(frame).mean(0)
                loss = F.mse_loss(out_fr, label_onehot)
                test_samples += label.numel()
                test_loss += loss.item() * label.numel()
                test_acc += (out_fr.argmax(1) == label).float().sum().item()
                functional.reset_net(net)
        test_time = time.time()
        test_speed = test_samples / (test_time - train_time)
        test_loss /= test_samples
        test_acc /= test_samples
        writer.add_scalar('test_speed', test_speed, epoch)
        writer.add_scalar('test_loss', test_loss, epoch)
        writer.add_scalar('test_acc', test_acc, epoch)

        save_max = False
        if test_acc > max_test_acc:
            max_test_acc = test_acc
            save_max = True

        checkpoint = {
            'net': net.state_dict(),
            'optimizer': optimizer.state_dict(),
            'lr_scheduler': lr_scheduler.state_dict(),
            'epoch': epoch,
            'max_test_acc': max_test_acc
        }

        if save_max:
            torch.save(checkpoint, os.path.join(out_dir, 'checkpoint_max.pth'))

        torch.save(checkpoint, os.path.join(out_dir, 'checkpoint_latest.pth'))

        print(args)
        print(out_dir)
        print(f'epoch = {epoch}, train_loss ={train_loss: .4f}, train_acc ={train_acc: .4f}, test_loss ={test_loss: .4f}, test_acc ={test_acc: .4f}, max_test_acc ={max_test_acc: .4f}')
        print(f'train speed ={train_speed: .4f} images/s, test speed ={test_speed: .4f} images/s')
        print(f'escape time = {(datetime.datetime.now() + datetime.timedelta(seconds=(time.time() - start_time) * (args.epochs - epoch))).strftime("%Y-%m-%d %H:%M:%S")}\n')

# %%
if __name__ == '__main__':
    main()
# Out:
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# DVSGestureNet(
#   (conv_fc): Sequential(
#     (0): Conv2d(2, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, step_mode=m)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True, step_mode=m)
#     (2): LIFNode(
#       v_threshold=1.0, v_reset=0.0, detach_reset=True, step_mode=m, backend=cupy, tau=2.0
#       (surrogate_function): ATan(alpha=2.0, spiking=True)
#     )
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False, step_mode=m)
#     (4): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, step_mode=m)
#     (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True, step_mode=m)
#     (6): LIFNode(
#       v_threshold=1.0, v_reset=0.0, detach_reset=True, step_mode=m, backend=cupy, tau=2.0
#       (surrogate_function): ATan(alpha=2.0, spiking=True)
#     )
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False, step_mode=m)
#     (8): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, step_mode=m)
#     (9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True, step_mode=m)
#     (10): LIFNode(
#       v_threshold=1.0, v_reset=0.0, detach_reset=True, step_mode=m, backend=cupy, tau=2.0
#       (surrogate_function): ATan(alpha=2.0, spiking=True)
#     )
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False, step_mode=m)
#     (12): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, step_mode=m)
#     (13): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True, step_mode=m)
#     (14): LIFNode(
#       v_threshold=1.0, v_reset=0.0, detach_reset=True, step_mode=m, backend=cupy, tau=2.0
#       (surrogate_function): ATan(alpha=2.0, spiking=True)
#     )
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False, step_mode=m)
#     (16): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, step_mode=m)
#     (17): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True, step_mode=m)
#     (18): LIFNode(
#       v_threshold=1.0, v_reset=0.0, detach_reset=True, step_mode=m, backend=cupy, tau=2.0
#       (surrogate_function): ATan(alpha=2.0, spiking=True)
#     )
#     (19): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False, step_mode=m)
#     (20): Flatten(start_dim=1, end_dim=-1, step_mode=m)
#     (21): Dropout(p=0.5)
#     (22): Linear(in_features=2048, out_features=512, bias=True)
#     (23): LIFNode(
#       v_threshold=1.0, v_reset=0.0, detach_reset=True, step_mode=m, backend=cupy, tau=2.0
#       (surrogate_function): ATan(alpha=2.0, spiking=True)
#     )
#     (24): Dropout(p=0.5)
#     (25): Linear(in_features=512, out_features=110, bias=True)
#     (26): LIFNode(
#       v_threshold=1.0, v_reset=0.0, detach_reset=True, step_mode=m, backend=cupy, tau=2.0
#       (surrogate_function): ATan(alpha=2.0, spiking=True)
#     )
#     (27): VotingLayer(voting_size=10, step_mode=m)
#   )
# )
# The directory [../datasets/DVS128Gesture\frames_number_16_split_by_number] already exists.
# The directory [../datasets/DVS128Gesture\frames_number_16_split_by_number] already exists.
# Mkdir ./logs\T16_b16_adam_lr0.001_c128_amp_cupy.
# C:\Users\jiaryWin\AppData\Local\Temp\ipykernel_26524\1228874622.py:62: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = amp.GradScaler()
# C:\Users\jiaryWin\AppData\Local\Temp\ipykernel_26524\1228874622.py:117: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 0, train_loss = 0.0663, train_acc = 0.3990, test_loss = 0.0496, test_acc = 0.5972, max_test_acc = 0.5972
# train speed = 9.3953 images/s, test speed = 6.5369 images/s
# escape time = 2025-06-04 22:32:15
#
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 1, train_loss = 0.0456, train_acc = 0.6190, test_loss = 0.0426, test_acc = 0.6736, max_test_acc = 0.6736
# train speed = 7.1714 images/s, test speed = 6.8041 images/s
# escape time = 2025-06-04 23:11:31
#
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 2, train_loss = 0.0393, train_acc = 0.6738, test_loss = 0.0393, test_acc = 0.6597, max_test_acc = 0.6736
# train speed = 7.1744 images/s, test speed = 6.6517 images/s
# escape time = 2025-06-04 23:12:27
#
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 3, train_loss = 0.0353, train_acc = 0.7226, test_loss = 0.0426, test_acc = 0.6250, max_test_acc = 0.6736
# train speed = 7.1916 images/s, test speed = 6.7804 images/s
# escape time = 2025-06-04 23:11:11
#
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 4, train_loss = 0.0322, train_acc = 0.7432, test_loss = 0.0332, test_acc = 0.7292, max_test_acc = 0.7292
# train speed = 7.1858 images/s, test speed = 6.7968 images/s
# escape time = 2025-06-04 23:11:14
#
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 5, train_loss = 0.0306, train_acc = 0.7526, test_loss = 0.0340, test_acc = 0.7431, max_test_acc = 0.7431
# train speed = 7.1887 images/s, test speed = 6.6773 images/s
# escape time = 2025-06-04 23:11:57
#
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 6, train_loss = 0.0282, train_acc = 0.7740, test_loss = 0.0318, test_acc = 0.7569, max_test_acc = 0.7569
# train speed = 7.1839 images/s, test speed = 6.6431 images/s
# escape time = 2025-06-04 23:12:15
#
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 7, train_loss = 0.0250, train_acc = 0.8082, test_loss = 0.0337, test_acc = 0.7014, max_test_acc = 0.7569
# train speed = 7.1844 images/s, test speed = 6.6472 images/s
# escape time = 2025-06-04 23:12:12
#
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 8, train_loss = 0.0241, train_acc = 0.8108, test_loss = 0.0274, test_acc = 0.7986, max_test_acc = 0.7986
# train speed = 7.1842 images/s, test speed = 6.6428 images/s
# escape time = 2025-06-04 23:12:15
#
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 9, train_loss = 0.0233, train_acc = 0.8219, test_loss = 0.0291, test_acc = 0.7569, max_test_acc = 0.7986
# train speed = 7.1882 images/s, test speed = 6.7045 images/s
# escape time = 2025-06-04 23:11:47
#
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 10, train_loss = 0.0216, train_acc = 0.8433, test_loss = 0.0268, test_acc = 0.8160, max_test_acc = 0.8160
# train speed = 7.1878 images/s, test speed = 6.6278 images/s
# escape time = 2025-06-04 23:12:16
#
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 11, train_loss = 0.0207, train_acc = 0.8579, test_loss = 0.0291, test_acc = 0.7847, max_test_acc = 0.8160
# train speed = 7.1603 images/s, test speed = 6.4960 images/s
# escape time = 2025-06-04 23:13:36
#
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 12, train_loss = 0.0195, train_acc = 0.8639, test_loss = 0.0289, test_acc = 0.7778, max_test_acc = 0.8160
# train speed = 7.1572 images/s, test speed = 6.7147 images/s
# escape time = 2025-06-04 23:12:24
#
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 13, train_loss = 0.0175, train_acc = 0.8870, test_loss = 0.0242, test_acc = 0.8264, max_test_acc = 0.8264
# train speed = 7.0493 images/s, test speed = 6.8367 images/s
# escape time = 2025-06-04 23:13:55
#
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 14, train_loss = 0.0164, train_acc = 0.8964, test_loss = 0.0209, test_acc = 0.8611, max_test_acc = 0.8611
# train speed = 7.2093 images/s, test speed = 6.7178 images/s
# escape time = 2025-06-04 23:11:25
#
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 15, train_loss = 0.0165, train_acc = 0.8896, test_loss = 0.0244, test_acc = 0.8160, max_test_acc = 0.8611
# train speed = 7.2016 images/s, test speed = 6.7862 images/s
# escape time = 2025-06-04 23:11:11
#
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 16, train_loss = 0.0145, train_acc = 0.9127, test_loss = 0.0198, test_acc = 0.8681, max_test_acc = 0.8681
# train speed = 7.1882 images/s, test speed = 6.7905 images/s
# escape time = 2025-06-04 23:11:25
#
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 17, train_loss = 0.0138, train_acc = 0.9144, test_loss = 0.0233, test_acc = 0.8438, max_test_acc = 0.8681
# train speed = 7.1953 images/s, test speed = 6.7105 images/s
# escape time = 2025-06-04 23:11:42
#
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 18, train_loss = 0.0147, train_acc = 0.9084, test_loss = 0.0234, test_acc = 0.8472, max_test_acc = 0.8681
# train speed = 7.1038 images/s, test speed = 6.8273 images/s
# escape time = 2025-06-04 23:12:45
#
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 19, train_loss = 0.0111, train_acc = 0.9443, test_loss = 0.0163, test_acc = 0.9028, max_test_acc = 0.9028
# train speed = 7.1675 images/s, test speed = 6.6968 images/s
# escape time = 2025-06-04 23:12:17
#
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 20, train_loss = 0.0107, train_acc = 0.9443, test_loss = 0.0151, test_acc = 0.9062, max_test_acc = 0.9062
# train speed = 7.0893 images/s, test speed = 6.6479 images/s
# escape time = 2025-06-04 23:13:52
#
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 21, train_loss = 0.0105, train_acc = 0.9452, test_loss = 0.0167, test_acc = 0.8889, max_test_acc = 0.9062
# train speed = 7.0512 images/s, test speed = 6.6437 images/s
# escape time = 2025-06-04 23:14:32
#
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 22, train_loss = 0.0093, train_acc = 0.9521, test_loss = 0.0148, test_acc = 0.9167, max_test_acc = 0.9167
# train speed = 6.9957 images/s, test speed = 6.6805 images/s
# escape time = 2025-06-04 23:15:19
#
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 23, train_loss = 0.0088, train_acc = 0.9623, test_loss = 0.0154, test_acc = 0.9167, max_test_acc = 0.9167
# train speed = 7.0975 images/s, test speed = 6.6439 images/s
# escape time = 2025-06-04 23:13:46
#
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 24, train_loss = 0.0076, train_acc = 0.9649, test_loss = 0.0142, test_acc = 0.9097, max_test_acc = 0.9167
# train speed = 7.2296 images/s, test speed = 6.7036 images/s
# escape time = 2025-06-04 23:11:27
#
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 25, train_loss = 0.0069, train_acc = 0.9709, test_loss = 0.0187, test_acc = 0.8611, max_test_acc = 0.9167
# train speed = 7.0972 images/s, test speed = 6.8111 images/s
# escape time = 2025-06-04 23:13:01
#
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 26, train_loss = 0.0062, train_acc = 0.9726, test_loss = 0.0137, test_acc = 0.9097, max_test_acc = 0.9167
# train speed = 7.2153 images/s, test speed = 6.6106 images/s
# escape time = 2025-06-04 23:12:06
#
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 27, train_loss = 0.0049, train_acc = 0.9837, test_loss = 0.0149, test_acc = 0.9097, max_test_acc = 0.9167
# train speed = 7.0831 images/s, test speed = 6.7427 images/s
# escape time = 2025-06-04 23:13:28
#
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 28, train_loss = 0.0055, train_acc = 0.9803, test_loss = 0.0150, test_acc = 0.9028, max_test_acc = 0.9167
# train speed = 7.1641 images/s, test speed = 6.7386 images/s
# escape time = 2025-06-04 23:12:21
#
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 29, train_loss = 0.0044, train_acc = 0.9820, test_loss = 0.0156, test_acc = 0.9062, max_test_acc = 0.9167
# train speed = 7.1752 images/s, test speed = 6.7719 images/s
# escape time = 2025-06-04 23:12:04
#
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 30, train_loss = 0.0046, train_acc = 0.9880, test_loss = 0.0165, test_acc = 0.8854, max_test_acc = 0.9167
# train speed = 7.2035 images/s, test speed = 6.7973 images/s
# escape time = 2025-06-04 23:11:36
#
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 31, train_loss = 0.0041, train_acc = 0.9872, test_loss = 0.0138, test_acc = 0.9062, max_test_acc = 0.9167
# train speed = 7.2082 images/s, test speed = 6.8289 images/s
# escape time = 2025-06-04 23:11:26
#
# Namespace(T=16, device='cuda:0', b=16, epochs=64, j=4, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy
# epoch = 32, train_loss = 0.0040, train_acc = 0.9872, test_loss = 0.0129, test_acc = 0.9201, max_test_acc = 0.9201
# train speed = 7.2217 images/s, test speed = 6.8404 images/s
# escape time = 2025-06-04 23:11:14
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 if __name__ == '__main__':
# ----> 2     main()
#
# Cell In[14], line 157, in main()
#     155 loss = F.mse_loss(out_fr, label_onehot)
#     156 test_samples += label.numel()
# --> 157 test_loss += loss.item() * label.numel()
#     158 test_acc += (out_fr.argmax(1) == label).float().sum().item()
#     159 functional.reset_net(net)
#
# KeyboardInterrupt:
