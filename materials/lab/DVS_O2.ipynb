# %%
import torch
import sys
import torch.nn.functional as F
from torch.cuda import amp
from spikingjelly.activation_based import functional, surrogate, neuron
from spikingjelly.activation_based.model import parametric_lif_net
from spikingjelly.datasets.dvs128_gesture import DVS128Gesture
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
import time
import os
import argparse
import datetime

# %%
import numpy as np
if not hasattr(np, 'int'):
    np.int = int

# %%
from spikingjelly.datasets.dvs128_gesture import DVS128Gesture
root_dir = '../datasets/DVS128Gesture'

# %%
#空间-时间-极性一致性滤波
from typing import Dict
import numpy as np
import spikingjelly.datasets as sjds
from scipy.spatial import cKDTree

def polarity_consistent_filter_events(events: Dict, min_neighbors=1, time_window=1000):
    """
    空间-时间-极性一致性滤波
    """
    t, x, y, p = (events[key] for key in ('t', 'x', 'y', 'p'))
    features = np.stack([t // time_window, x, y], axis=1)
    tree = cKDTree(features)
    # 查询每个点的邻居索引
    neighbors = tree.query_ball_point(features, r=1)
    keep = []
    for i, idxs in enumerate(neighbors):
        # 统计极性一致的邻居数（包括自己）
        same_polarity = np.sum(p[idxs] == p[i])
        if same_polarity > min_neighbors:
            keep.append(i)
    keep = np.array(keep)
    return {
        't': t[keep],
        'x': x[keep],
        'y': y[keep],
        'p': p[keep]
    }

def integrate_events_to_2_frames_denoised2(events: Dict, H: int, W: int):
    # 用极性一致性滤波
    events = polarity_consistent_filter_events(events, min_neighbors=1, time_window=1000)
    if len(events['t']) == 0:
        return np.zeros([2, 2, H, W])
    index_split = np.random.randint(low=0, high=len(events['t']))
    frames = np.zeros([2, 2, H, W])
    t, x, y, p = (events[key] for key in ('t', 'x', 'y', 'p'))
    frames[0] = sjds.integrate_events_segment_to_frame(x, y, p, H, W, 0, index_split)
    frames[1] = sjds.integrate_events_segment_to_frame(x, y, p, H, W, index_split, len(t))
    return frames

def integrate_events_to_16_frames_by_time(events: Dict, H: int, W: int):
    if len(events['t']) == 0:
        return np.zeros([16, 2, H, W])

    events = polarity_consistent_filter_events(events, min_neighbors=1, time_window=1000)

    t = events['t']
    x = events['x']
    y = events['y']
    p = events['p']

    t_start = t[0]
    t_end = t[-1]
    total_duration = t_end - t_start
    base_delta = total_duration // 16
    remainder = total_duration % 16

    frames = np.zeros([16, 2, H, W], dtype=np.float32)

    for i in range(16):
        t_low = t_start + i * base_delta + min(i, remainder)
        t_high = t_low + base_delta + (1 if i < remainder else 0)
        mask = np.logical_and(t >= t_low, t < t_high)
        frame = sjds.integrate_events_segment_to_frame(x[mask], y[mask], p[mask], H, W)
        frames[i] = frame

    return frames

# %%
def main():
    # python -m spikingjelly.activation_based.examples.classify_dvsg -T 16 -device cuda:0 -b 16 -epochs 64 -data-dir /datasets/DVSGesture/ -amp -cupy -opt adam -lr 0.001 -j 8

    parser = argparse.ArgumentParser(description='Classify DVS Gesture')
    parser.add_argument('-T', default=16, type=int, help='simulating time-steps')                                   #   16
    parser.add_argument('-device', default='cuda:0', help='device')                                                 #   cuda:0    
    parser.add_argument('-b', default=16, type=int, help='batch size')                                               #   8
    parser.add_argument('-epochs', default=32, type=int, metavar='N',
                        help='number of total epochs to run')                                                       #   32
    parser.add_argument('-j', default=8, type=int, metavar='N',
                        help='number of data loading workers (default: 4)')                                         #   8
    parser.add_argument('-data-dir', type=str, help='root dir of DVS Gesture dataset',default='../datasets/DVS128Gesture')
    parser.add_argument('-out-dir', type=str, default='./logs', help='root dir for saving logs and checkpoint')
    parser.add_argument('-resume', type=str, help='resume from the checkpoint path')
    parser.add_argument('-amp', action='store_true', help='automatic mixed precision training',default= True)       #   amp
    parser.add_argument('-cupy', action='store_true', help='use cupy backend', default=True)                        #   cupy
    parser.add_argument('-opt', type=str, help='use which optimizer. SDG or Adam', default='adam')                  #   Adam
    parser.add_argument('-momentum', default=0.9, type=float, help='momentum for SGD')                              #   momentum = 0.9
    parser.add_argument('-lr', default=0.001, type=float, help='learning rate')                                    #   lr = 0.0003
    parser.add_argument('-channels', default=128, type=int, help='channels of CSNN')                                #   128

    args, _ = parser.parse_known_args()  # 忽略 Jupyter 自动添加的 -f 参数
    print(args)

    net = parametric_lif_net.DVSGestureNet(channels=args.channels, spiking_neuron=neuron.LIFNode, surrogate_function=surrogate.ATan(), detach_reset=True)

    functional.set_step_mode(net, 'm')
    if args.cupy:
        functional.set_backend(net, 'cupy', instance=neuron.LIFNode)

    print(net)


    net.to(args.device)

    #对模型进行量化为float16，BN位置则仍旧为float32
    # net.half()
    # for layer in net.modules():
    #     if isinstance(layer, torch.nn.BatchNorm2d):
    #         layer.float()  # BN 层保持 float32

    # 对模型进行减枝
    # import torch.nn.utils.prune as prune
    # for name, module in net.named_modules():
    #     if isinstance(module, torch.nn.Conv2d) or isinstance(module, torch.nn.Linear):
    #         prune.l1_unstructured(module, name='weight', amount=0.1)

    # train_set = DVS128Gesture(root=args.data_dir, train=True, data_type='frame', split_by='number',custom_integrate_function=integrate_events_to_2_frames_denoised2)
    # test_set = DVS128Gesture(root=args.data_dir, train=False, data_type='frame', split_by='number',custom_integrate_function=integrate_events_to_2_frames_denoised2)

    train_set = DVS128Gesture(root=args.data_dir, 
                          train=True, 
                          data_type='frame', 
                          split_by='number', 
                          custom_integrate_function=integrate_events_to_16_frames_by_time)
    # train_set = DVS128Gesture(root=args.data_dir, train=True, data_type='frame', frames_number=args.T, split_by='number')
    test_set = DVS128Gesture(root=args.data_dir, 
                          train=False, 
                          data_type='frame', 
                          split_by='number', 
                          custom_integrate_function=integrate_events_to_16_frames_by_time)
    # test_set = DVS128Gesture(root=args.data_dir, train=False, data_type='frame', frames_number=args.T, split_by='number')


    train_data_loader = torch.utils.data.DataLoader(
        dataset=train_set,
        batch_size=args.b,
        shuffle=True,
        drop_last=True,
        num_workers=args.j,
        pin_memory=True,
        prefetch_factor=2,  # 2 让每个worker获取更多batch
    )

    test_data_loader = torch.utils.data.DataLoader(
        dataset=test_set,
        batch_size=args.b,
        shuffle=True,
        drop_last=False,
        num_workers=args.j,
        pin_memory=True,
        prefetch_factor=2,  # 2 让每个worker获取更多batch
    )


    scaler = None
    if args.amp:
        scaler = amp.GradScaler()

    start_epoch = 0
    max_test_acc = -1

    optimizer = None
    if args.opt == 'sgd':
        optimizer = torch.optim.SGD(net.parameters(), lr=args.lr, momentum=args.momentum)
    elif args.opt == 'adam':
        optimizer = torch.optim.Adam(net.parameters(), lr=args.lr)
    else:
        raise NotImplementedError(args.opt)

    lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, args.epochs)

    if args.resume:
        checkpoint = torch.load(args.resume, map_location='cpu')
        net.load_state_dict(checkpoint['net'])
        optimizer.load_state_dict(checkpoint['optimizer'])
        lr_scheduler.load_state_dict(checkpoint['lr_scheduler'])
        start_epoch = checkpoint['epoch'] + 1
        max_test_acc = checkpoint['max_test_acc']

    out_dir = os.path.join(args.out_dir, f'T{args.T}_b{args.b}_{args.opt}_lr{args.lr}_c{args.channels}')

    if args.amp:
        out_dir += '_amp'

    if args.cupy:
        out_dir += '_cupy'
    out_dir += '_O2'
    if not os.path.exists(out_dir):
        os.makedirs(out_dir)
        print(f'Mkdir {out_dir}.')

    writer = SummaryWriter(out_dir, purge_step=start_epoch)
    with open(os.path.join(out_dir, 'args.txt'), 'w', encoding='utf-8') as args_txt:
        args_txt.write(str(args))
        args_txt.write('\n')
        args_txt.write(' '.join(sys.argv))

    for epoch in range(start_epoch, args.epochs):
        start_time = time.time()
        net.train()
        train_loss = 0
        train_acc = 0
        train_samples = 0
        for frame, label in train_data_loader:
            optimizer.zero_grad()
            frame = frame.to(args.device) #异步加载
            frame = frame.transpose(0, 1)  # [N, T, C, H, W] -> [T, N, C, H, W]
            label = label.to(args.device) #异步加载
            label_onehot = F.one_hot(label, 11).float()

            if scaler is not None:
                with amp.autocast():
                    out_fr = net(frame).mean(0)
                    loss = F.mse_loss(out_fr, label_onehot)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()
            else:
                out_fr = net(frame).mean(0)
                loss = F.mse_loss(out_fr, label_onehot)
                loss.backward()
                optimizer.step()

            train_samples += label.numel()
            train_loss += loss.item() * label.numel()
            train_acc += (out_fr.argmax(1) == label).float().sum().item()

            functional.reset_net(net)

        train_time = time.time()
        train_speed = train_samples / (train_time - start_time)
        train_loss /= train_samples
        train_acc /= train_samples

        writer.add_scalar('train_speed', train_speed, epoch) # 计算训练速度
        writer.add_scalar('train_loss', train_loss, epoch)
        writer.add_scalar('train_acc', train_acc, epoch)
        lr_scheduler.step()

        net.eval()
        test_loss = 0
        test_acc = 0
        test_samples = 0
        with torch.no_grad():
            for frame, label in test_data_loader:
                frame = frame.to(args.device) #异步加载
                frame = frame.transpose(0, 1)  # [N, T, C, H, W] -> [T, N, C, H, W]
                label = label.to(args.device) #异步加载
                label_onehot = F.one_hot(label, 11).float()
                out_fr = net(frame).mean(0)
                loss = F.mse_loss(out_fr, label_onehot)
                test_samples += label.numel()
                test_loss += loss.item() * label.numel()
                test_acc += (out_fr.argmax(1) == label).float().sum().item()
                functional.reset_net(net)
        test_time = time.time()
        test_speed = test_samples / (test_time - train_time)
        test_loss /= test_samples
        test_acc /= test_samples
        writer.add_scalar('test_speed', test_speed, epoch) # 计算测试速度
        writer.add_scalar('test_loss', test_loss, epoch)
        writer.add_scalar('test_acc', test_acc, epoch)

        save_max = False
        if test_acc > max_test_acc:
            max_test_acc = test_acc
            save_max = True

        checkpoint = {
            'net': net.state_dict(),
            'optimizer': optimizer.state_dict(),
            'lr_scheduler': lr_scheduler.state_dict(),
            'epoch': epoch,
            'max_test_acc': max_test_acc
        }

        if save_max:
            torch.save(checkpoint, os.path.join(out_dir, 'checkpoint_max.pth'))

        torch.save(checkpoint, os.path.join(out_dir, 'checkpoint_latest.pth'))

        print(args)
        print(out_dir)
        print(f'epoch = {epoch}, train_loss ={train_loss: .4f}, train_acc ={train_acc: .4f}, test_loss ={test_loss: .4f}, test_acc ={test_acc: .4f}, max_test_acc ={max_test_acc: .4f}')
        print(f'train speed ={train_speed: .4f} images/s, test speed ={test_speed: .4f} images/s')
        print(f'escape time = {(datetime.datetime.now() + datetime.timedelta(seconds=(time.time() - start_time) * (args.epochs - epoch))).strftime("%Y-%m-%d %H:%M:%S")}\n')

if __name__ == '__main__':
    main()
# Out:
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# DVSGestureNet(
#   (conv_fc): Sequential(
#     (0): Conv2d(2, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, step_mode=m)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True, step_mode=m)
#     (2): LIFNode(
#       v_threshold=1.0, v_reset=0.0, detach_reset=True, step_mode=m, backend=cupy, tau=2.0
#       (surrogate_function): ATan(alpha=2.0, spiking=True)
#     )
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False, step_mode=m)
#     (4): ResidualBlock(
#       (block): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, step_mode=m)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True, step_mode=m)
#         (2): LIFNode(
#           v_threshold=1.0, v_reset=0.0, detach_reset=True, step_mode=m, backend=cupy, tau=2.0
#           (surrogate_function): ATan(alpha=2.0, spiking=True)
#         )
#       )
#     )
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False, step_mode=m)
#     (6): ResidualBlock(
#       (block): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, step_mode=m)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True, step_mode=m)
#         (2): LIFNode(
#           v_threshold=1.0, v_reset=0.0, detach_reset=True, step_mode=m, backend=cupy, tau=2.0
#           (surrogate_function): ATan(alpha=2.0, spiking=True)
#         )
#       )
#     )
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False, step_mode=m)
#     (8): ResidualBlock(
#       (block): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, step_mode=m)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True, step_mode=m)
#         (2): LIFNode(
#           v_threshold=1.0, v_reset=0.0, detach_reset=True, step_mode=m, backend=cupy, tau=2.0
#           (surrogate_function): ATan(alpha=2.0, spiking=True)
#         )
#       )
#     )
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False, step_mode=m)
#     (10): ResidualBlock(
#       (block): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, step_mode=m)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True, step_mode=m)
#         (2): LIFNode(
#           v_threshold=1.0, v_reset=0.0, detach_reset=True, step_mode=m, backend=cupy, tau=2.0
#           (surrogate_function): ATan(alpha=2.0, spiking=True)
#         )
#       )
#     )
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False, step_mode=m)
#     (12): Flatten(start_dim=1, end_dim=-1, step_mode=m)
#     (13): Dropout(p=0.5)
#     (14): Linear(in_features=2048, out_features=512, bias=True)
#     (15): LIFNode(
#       v_threshold=1.0, v_reset=0.0, detach_reset=True, step_mode=m, backend=cupy, tau=2.0
#       (surrogate_function): ATan(alpha=2.0, spiking=True)
#     )
#     (16): Dropout(p=0.5)
#     (17): Linear(in_features=512, out_features=110, bias=True)
#     (18): LIFNode(
#       v_threshold=1.0, v_reset=0.0, detach_reset=True, step_mode=m, backend=cupy, tau=2.0
#       (surrogate_function): ATan(alpha=2.0, spiking=True)
#     )
#     (19): VotingLayer(voting_size=10, step_mode=m)
#   )
# )
# The directory [../datasets/DVS128Gesture\integrate_events_to_16_frames_by_time] already exists.
# The directory [../datasets/DVS128Gesture\integrate_events_to_16_frames_by_time] already exists.
# Mkdir ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2.
# C:\Users\jiaryWin\AppData\Local\Temp\ipykernel_16472\1517810617.py:88: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = amp.GradScaler()
# C:\Users\jiaryWin\AppData\Local\Temp\ipykernel_16472\1517810617.py:143: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2
# epoch = 0, train_loss = 0.0716, train_acc = 0.3211, test_loss = 0.0615, test_acc = 0.4688, max_test_acc = 0.4688
# train speed = 8.5383 images/s, test speed = 9.2485 images/s
# escape time = 2025-06-11 10:53:26
#
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2
# epoch = 1, train_loss = 0.0558, train_acc = 0.5402, test_loss = 0.0526, test_acc = 0.5521, max_test_acc = 0.5521
# train speed = 8.6023 images/s, test speed = 9.2580 images/s
# escape time = 2025-06-11 10:52:52
#
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2
# epoch = 2, train_loss = 0.0500, train_acc = 0.5693, test_loss = 0.0490, test_acc = 0.5694, max_test_acc = 0.5694
# train speed = 8.5705 images/s, test speed = 9.1421 images/s
# escape time = 2025-06-11 10:53:20
#
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2
# epoch = 3, train_loss = 0.0474, train_acc = 0.6002, test_loss = 0.0452, test_acc = 0.6181, max_test_acc = 0.6181
# train speed = 8.5268 images/s, test speed = 9.1320 images/s
# escape time = 2025-06-11 10:53:42
#
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2
# epoch = 4, train_loss = 0.0441, train_acc = 0.6370, test_loss = 0.0437, test_acc = 0.6354, max_test_acc = 0.6354
# train speed = 8.5255 images/s, test speed = 9.0891 images/s
# escape time = 2025-06-11 10:53:47
#
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2
# epoch = 5, train_loss = 0.0429, train_acc = 0.6421, test_loss = 0.0419, test_acc = 0.6319, max_test_acc = 0.6354
# train speed = 8.5542 images/s, test speed = 9.0673 images/s
# escape time = 2025-06-11 10:53:36
#
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2
# epoch = 6, train_loss = 0.0405, train_acc = 0.6729, test_loss = 0.0410, test_acc = 0.6458, max_test_acc = 0.6458
# train speed = 8.5391 images/s, test speed = 9.0665 images/s
# escape time = 2025-06-11 10:53:43
#
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2
# epoch = 7, train_loss = 0.0386, train_acc = 0.6909, test_loss = 0.0395, test_acc = 0.6840, max_test_acc = 0.6840
# train speed = 8.4706 images/s, test speed = 9.1069 images/s
# escape time = 2025-06-11 10:54:08
#
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2
# epoch = 8, train_loss = 0.0372, train_acc = 0.6918, test_loss = 0.0379, test_acc = 0.6944, max_test_acc = 0.6944
# train speed = 8.5323 images/s, test speed = 9.0514 images/s
# escape time = 2025-06-11 10:53:48
#
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2
# epoch = 9, train_loss = 0.0349, train_acc = 0.7072, test_loss = 0.0379, test_acc = 0.6979, max_test_acc = 0.6979
# train speed = 8.5297 images/s, test speed = 9.0181 images/s
# escape time = 2025-06-11 10:53:52
#
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2
# epoch = 10, train_loss = 0.0333, train_acc = 0.7183, test_loss = 0.0331, test_acc = 0.7188, max_test_acc = 0.7188
# train speed = 8.5026 images/s, test speed = 9.0578 images/s
# escape time = 2025-06-11 10:53:59
#
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2
# epoch = 11, train_loss = 0.0312, train_acc = 0.7346, test_loss = 0.0327, test_acc = 0.7361, max_test_acc = 0.7361
# train speed = 8.5568 images/s, test speed = 9.0632 images/s
# escape time = 2025-06-11 10:53:39
#
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2
# epoch = 12, train_loss = 0.0290, train_acc = 0.7603, test_loss = 0.0329, test_acc = 0.7292, max_test_acc = 0.7361
# train speed = 8.5199 images/s, test speed = 9.0588 images/s
# escape time = 2025-06-11 10:53:51
#
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2
# epoch = 13, train_loss = 0.0285, train_acc = 0.7637, test_loss = 0.0311, test_acc = 0.7396, max_test_acc = 0.7396
# train speed = 8.5390 images/s, test speed = 9.0719 images/s
# escape time = 2025-06-11 10:53:45
#
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2
# epoch = 14, train_loss = 0.0275, train_acc = 0.7680, test_loss = 0.0299, test_acc = 0.7500, max_test_acc = 0.7500
# train speed = 8.5039 images/s, test speed = 9.0650 images/s
# escape time = 2025-06-11 10:53:56
#
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2
# epoch = 15, train_loss = 0.0265, train_acc = 0.7842, test_loss = 0.0290, test_acc = 0.7812, max_test_acc = 0.7812
# train speed = 8.5436 images/s, test speed = 9.0621 images/s
# escape time = 2025-06-11 10:53:44
#
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2
# epoch = 16, train_loss = 0.0256, train_acc = 0.7834, test_loss = 0.0296, test_acc = 0.7569, max_test_acc = 0.7812
# train speed = 8.5048 images/s, test speed = 9.0696 images/s
# escape time = 2025-06-11 10:53:54
#
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2
# epoch = 17, train_loss = 0.0243, train_acc = 0.8014, test_loss = 0.0294, test_acc = 0.7674, max_test_acc = 0.7812
# train speed = 8.4981 images/s, test speed = 9.0857 images/s
# escape time = 2025-06-11 10:53:55
#
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2
# epoch = 18, train_loss = 0.0239, train_acc = 0.8125, test_loss = 0.0288, test_acc = 0.7604, max_test_acc = 0.7812
# train speed = 8.5009 images/s, test speed = 9.0588 images/s
# escape time = 2025-06-11 10:53:56
#
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2
# epoch = 19, train_loss = 0.0230, train_acc = 0.8176, test_loss = 0.0284, test_acc = 0.7674, max_test_acc = 0.7812
# train speed = 8.5429 images/s, test speed = 9.0674 images/s
# escape time = 2025-06-11 10:53:46
#
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2
# epoch = 20, train_loss = 0.0229, train_acc = 0.8253, test_loss = 0.0280, test_acc = 0.7951, max_test_acc = 0.7951
# train speed = 8.5284 images/s, test speed = 8.9551 images/s
# escape time = 2025-06-11 10:53:54
#
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2
# epoch = 21, train_loss = 0.0225, train_acc = 0.8125, test_loss = 0.0298, test_acc = 0.7465, max_test_acc = 0.7951
# train speed = 8.4852 images/s, test speed = 9.0647 images/s
# escape time = 2025-06-11 10:53:58
#
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2
# epoch = 22, train_loss = 0.0223, train_acc = 0.8262, test_loss = 0.0314, test_acc = 0.7639, max_test_acc = 0.7951
# train speed = 8.5391 images/s, test speed = 9.0484 images/s
# escape time = 2025-06-11 10:53:49
#
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2
# epoch = 23, train_loss = 0.0218, train_acc = 0.8271, test_loss = 0.0279, test_acc = 0.7812, max_test_acc = 0.7951
# train speed = 8.4617 images/s, test speed = 5.9418 images/s
# escape time = 2025-06-11 10:56:48
#
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2
# epoch = 24, train_loss = 0.0215, train_acc = 0.8365, test_loss = 0.0282, test_acc = 0.7847, max_test_acc = 0.7951
# train speed = 8.4861 images/s, test speed = 9.0452 images/s
# escape time = 2025-06-11 10:54:15
#
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2
# epoch = 25, train_loss = 0.0209, train_acc = 0.8356, test_loss = 0.0280, test_acc = 0.7986, max_test_acc = 0.7986
# train speed = 8.4655 images/s, test speed = 8.4516 images/s
# escape time = 2025-06-11 10:54:35
#
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2
# epoch = 26, train_loss = 0.0207, train_acc = 0.8562, test_loss = 0.0280, test_acc = 0.8090, max_test_acc = 0.8090
# train speed = 8.4121 images/s, test speed = 9.0041 images/s
# escape time = 2025-06-11 10:54:27
#
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2
# epoch = 27, train_loss = 0.0208, train_acc = 0.8416, test_loss = 0.0274, test_acc = 0.7986, max_test_acc = 0.8090
# train speed = 8.4850 images/s, test speed = 8.6105 images/s
# escape time = 2025-06-11 10:54:28
#
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2
# epoch = 28, train_loss = 0.0206, train_acc = 0.8433, test_loss = 0.0277, test_acc = 0.7917, max_test_acc = 0.8090
# train speed = 8.4653 images/s, test speed = 9.0584 images/s
# escape time = 2025-06-11 10:54:22
#
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2
# epoch = 29, train_loss = 0.0204, train_acc = 0.8536, test_loss = 0.0274, test_acc = 0.7917, max_test_acc = 0.8090
# train speed = 8.4684 images/s, test speed = 8.8877 images/s
# escape time = 2025-06-11 10:54:24
#
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2
# epoch = 30, train_loss = 0.0208, train_acc = 0.8493, test_loss = 0.0278, test_acc = 0.7882, max_test_acc = 0.8090
# train speed = 8.3046 images/s, test speed = 9.0367 images/s
# escape time = 2025-06-11 10:54:31
#
# Namespace(T=16, device='cuda:0', b=16, epochs=32, j=8, data_dir='../datasets/DVS128Gesture', out_dir='./logs', resume=None, amp=True, cupy=True, opt='adam', momentum=0.9, lr=0.001, channels=128)
# ./logs\T16_b16_adam_lr0.001_c128_amp_cupy_O2
# epoch = 31, train_loss = 0.0201, train_acc = 0.8382, test_loss = 0.0276, test_acc = 0.7951, max_test_acc = 0.8090
# train speed = 8.5062 images/s, test speed = 9.1199 images/s
# escape time = 2025-06-11 10:54:23
